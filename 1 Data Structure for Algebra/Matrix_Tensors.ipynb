# %%
# buat matrix X berukuran 2x3 menggunakan numpy
import numpy as np

# %%
X = np.array([[77, 7], [5, 10], [4, 8]])
X
# Out:
# array([[77,  7],
#        [ 5, 10],
#        [ 4,  8]])

# %%
# tampilkan ukuran dari matrix X
X.shape
# Out:
# (3, 2)

# %%
X.size
# Out:
# 6

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X[0,:]
# Out:
# array([77,  7])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
X[:,1]
# Out:
# array([ 7, 10,  8])

# %%
# ulangi soal nomor 1 menggunakan pytorch
import torch

# %%
X_pt = torch.tensor([[77, 7], [5, 10], [4, 8]])
X_pt
# Out:
# tensor([[77,  7],
#         [ 5, 10],
#         [ 4,  8]])

# %%
X_pt.shape
# Out:
# torch.Size([3, 2])

# %%
X_pt.size
# Out:
# <function Tensor.size>

# %%
X_pt[0,:]
# Out:
# tensor([77,  7])

# %%
X_pt[:,1]
# Out:
# tensor([ 7, 10,  8])

# %%
# ulangi soal nomor 1 menggunakan tensorflow
import tensorflow as tf

# %%
X_tf = tf.Variable([[77, 7], [5, 10], [4, 8]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[77,  7],
#        [ 5, 10],
#        [ 4,  8]], dtype=int32)>

# %%
tf.shape(X_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([3, 2], dtype=int32)>

# %%
tf.size(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=6>

# %%
X_tf[0,:]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([77,  7], dtype=int32)>

# %%
X_tf[:,1]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([ 7, 10,  8], dtype=int32)>
