# %%
# buat skalar x dan simpan suatu nilai skalar
x = 77
x
# Out:
# 77

# %%
# tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 7

# %%
# tampilkan tipe data dari y
type(y)
# Out:
# int

# %%
# jumlahkan x+y
py_sum = x + y
py_sum
# Out:
# 84

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 77.0

# %%
# jumlahkan x_float dengan y
float_sum = x_float + y
float_sum
# Out:
# 84.0

# %%
# tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %%
# lakukan tahapan pada soal 1 dengan menggunakan tensorflow
import tensorflow as tf

# %%
x_tf = tf.Variable(77, dtype=tf.int16)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=77>

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
y_tf = tf.Variable(7, dtype=tf.int16)

# %%
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=84>

# %%
tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=84>

# %%
tf_sum.numpy()
# Out:
# np.int16(84)

# %%
type(tf_sum.numpy())
# Out:
# numpy.int16

# %%
tf_float = tf.Variable(77., dtype=tf.float16)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=77.0>

# %%
# lakukan tahapan pada soal 1 dengan menggunakan pytorch
import torch

# %%
x_pt = torch.tensor(77)
x_pt
# Out:
# tensor(77)

# %%
x_pt.shape
# Out:
# torch.Size([])
