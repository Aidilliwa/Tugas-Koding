# %%
# selesaikan soal berikut
# 1. What is the transpose of this vector?
import numpy as np

v = np.array([[25], [2], [-3], [-23]])
v
# Out:
# array([[ 25],
#        [  2],
#        [ -3],
#        [-23]])

# %%
# transpose
v_t = v.T
v_t
# Out:
# array([[ 25,   2,  -3, -23]])
